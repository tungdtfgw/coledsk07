# %%
x = 10
print(x, type(x))
x = 3.14
print(x, type(x))
x = "Hello"     # 'Hello'
print(x, type(x))
x = True
print(x, type(x))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Hello <class 'str'>
# True <class 'bool'>

# %%
a = [1, 3, 5, 9, 12, 33]
print(a, type(a))
print(a[0], a[2])
# Out:
# [1, 3, 5, 9, 12, 33] <class 'list'>
# 1 5

# %%
en_vi = {
    'hello' : 'xin chào',
    'cat'   : 'con mèo',
    'dog'   : 'con chó',
    'red'   : 'màu đỏ',
}
print(en_vi['cat'])
# Out:
# con mèo

# %%
print(a)
name = input('Enter your name: ')
print('Hello', name)
# Out:
# [1, 3, 5, 9, 12, 33]
# Hello Tung

# %%
yob = int(input('Enter your year of birth: '))
age = 2025 - yob
print('You are', age, 'years old.')
# Out:
# You are 25 years old.
